# %%
#mod1.py

def add(a,b):
  return a + b

def sub (a, b):
  return a - b

if __name__ = "__main__":
  print(add(4,5))
  print(sub(5,2))
# Out:
#   File "<ipython-input-5-b39b59f80f29>", line 9
#     if __name__ = "__main__":
#                 ^
# SyntaxError: invalid syntax
